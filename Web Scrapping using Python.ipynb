# %%
greetings = "Assalam-o-Alaikum!"
print(greetings)
# Out:
# Assalam-o-Alaikum!

# %% [markdown]
# ### Import Libraries

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import folium

# %% [markdown]
# ### Import Data

# %%
data = pd.read_html("https://s3.amazonaws.com/codecademy-content/courses/beautifulsoup/cacao/index.html")

# %%
df = data[1]
df.head(5)
# Out:
#                           0                                  1     2  \
# 0  Company (Maker-if known)  Specific Bean Origin  or Bar Name   REF
# 1                  A. Morin                        Agua Grande  1876
# 2                  A. Morin                              Kpime  1676
# 3                  A. Morin                             Atsane  1676
# 4                  A. Morin                              Akata  1680
#
#               3               4                  5       6           7  \
# 0  Review  Date  Cocoa  Percent  Company  Location  Rating  Bean  Type
# 1          2016             63%             France    3.75         NaN
# 2          2015             70%             France    2.75         NaN
# 3          2015             70%             France       3         NaN
# 4          2015             70%             France     3.5         NaN
#
#                     8
# 0  Broad Bean  Origin
# 1            Sao Tome
# 2                Togo
# 3                Togo
# 4                Togo

# %% [markdown]
# **Set Columns**

# %%
df.columns = df.iloc[0]
df = df.drop(df.index[0])
df.head(5)
# Out:
# 0 Company (Maker-if known) Specific Bean Origin  or Bar Name   REF  \
# 1                 A. Morin                       Agua Grande  1876
# 2                 A. Morin                             Kpime  1676
# 3                 A. Morin                            Atsane  1676
# 4                 A. Morin                             Akata  1680
# 5                 A. Morin                            Quilla  1704
#
# 0 Review  Date Cocoa  Percent Company  Location Rating Bean  Type  \
# 1         2016            63%            France   3.75        NaN
# 2         2015            70%            France   2.75        NaN
# 3         2015            70%            France      3        NaN
# 4         2015            70%            France    3.5        NaN
# 5         2015            70%            France    3.5        NaN
#
# 0 Broad Bean  Origin
# 1           Sao Tome
# 2               Togo
# 3               Togo
# 4               Togo
# 5               Peru

# %% [markdown]
# **Drop unnecessary columns**

# %%
df = df.drop(columns = ["REF"])

# %% [markdown]
# **Rename Columns**

# %%
df = df.rename(columns = {"Company (Maker-if known)": "Company", 
                          "Specific Bean Origin  or Bar Name": "Bar Area",
                          "Review  Date": "Review Date",
                          "Cocoa  Percent": "Cocoa Percent",
                          "Company  Location": "Location",
                          "Bean  Type": "Bean Type",
                          "Broad Bean  Origin": "Broad Bean Origin"})
df.sample(5)
# Out:
# 0                        Company                Bar Area Review Date  \
# 350                    Caribeans  Anselmo Paraiso Estate        2015
# 574                       Domori  Ocumare 67, Puertofino        2007
# 1778                      Zokoko    Tranquilidad, Baures        2011
# 1155        Muchomas (Mesocacao)               Nicaragua        2015
# 832   Hotel Chocolat (Coppeneur)       Los Rios, H. Iara        2013
#
# 0    Cocoa Percent    Location Rating             Bean Type Broad Bean Origin
# 350            72%  Costa Rica    3.5                   NaN        Costa Rica
# 574            70%       Italy      4  Criollo (Ocumare 67)         Venezuela
# 1778           72%   Australia   3.75                   NaN           Bolivia
# 1155           70%      U.S.A.    3.5                   NaN         Nicaragua
# 832            90%        U.K.      3  Forastero (Nacional)           Ecuador

# %% [markdown]
# **Remove Percentage Sign from Cocoa Percent**

# %%
df["Cocoa Percent"] = df['Cocoa Percent'].str.rstrip('%').astype("float")

# %% [markdown]
# **Change Datatypes of Review Date and Rating**

# %%
df["Review Date"] = df["Review Date"].astype("int")
df["Rating"] = df["Rating"].astype("float")

# %%
df.sample(5)
# Out:
# 0                 Company                               Bar Area  Review Date  \
# 587               Duffy's                     Dominican Republic         2011
# 716   Friis Holm (Bonnat)                             Johe, Xoco         2011
# 610              El Ceibo                              Alto Beni         2008
# 1702             Valrhona  Porcelana, Maracaibo, Palmira P. 2005         2006
# 1731                Vivra                                Ocumare         2016
#
# 0     Cocoa Percent Location  Rating            Bean Type   Broad Bean Origin
# 587            65.0     U.K.    3.50                  NaN  Dominican Republic
# 716            70.0  Denmark    3.25  Criollo, Trinitario           Nicaragua
# 610            71.0  Bolivia    2.75                  NaN             Bolivia
# 1702           64.0   France    3.00  Criollo (Porcelana)           Venezuela
# 1731           70.0   U.S.A.    2.50                  NaN           Venezuela

# %%
df["Location"] = df["Location"].replace(["U.S.A.", "U.K."], ["United States", "United Kingdom"])

# %%
pd.set_option('display.max_rows', df.shape[0]+1)

# %% [markdown]
# **Coordinates**

# %%
dfc = pd.read_html("https://developers.google.com/public-data/docs/canonical/countries_csv")

# %%
data = dfc[0]
data.head()
# Out:
#   country   latitude  longitude                  name
# 0      AD  42.546245   1.601554               Andorra
# 1      AE  23.424076  53.847818  United Arab Emirates
# 2      AF  33.939110  67.709953           Afghanistan
# 3      AG  17.060816 -61.796428   Antigua and Barbuda
# 4      AI  18.220554 -63.068615              Anguilla

# %%
data = data.drop(columns = ["country"])

# %%
data.columns = ["latitude", "longitude", "Location"]

# %%
dfr = pd.merge(df, data, on = "Location", how = "outer")
dfr.head()
# Out:
#     Company     Bar Area  Review Date  Cocoa Percent Location  Rating  \
# 0  A. Morin  Agua Grande       2016.0           63.0   France    3.75
# 1  A. Morin        Kpime       2015.0           70.0   France    2.75
# 2  A. Morin       Atsane       2015.0           70.0   France    3.00
# 3  A. Morin        Akata       2015.0           70.0   France    3.50
# 4  A. Morin       Quilla       2015.0           70.0   France    3.50
#
#   Bean Type Broad Bean Origin   latitude  longitude
# 0       NaN          Sao Tome  46.227638   2.213749
# 1       NaN              Togo  46.227638   2.213749
# 2       NaN              Togo  46.227638   2.213749
# 3       NaN              Togo  46.227638   2.213749
# 4       NaN              Peru  46.227638   2.213749

# %%
dfr = dfr.dropna(subset = ["latitude", "longitude"])
dfr.head()
# Out:
#     Company     Bar Area  Review Date  Cocoa Percent Location  Rating  \
# 0  A. Morin  Agua Grande       2016.0           63.0   France    3.75
# 1  A. Morin        Kpime       2015.0           70.0   France    2.75
# 2  A. Morin       Atsane       2015.0           70.0   France    3.00
# 3  A. Morin        Akata       2015.0           70.0   France    3.50
# 4  A. Morin       Quilla       2015.0           70.0   France    3.50
#
#   Bean Type Broad Bean Origin   latitude  longitude
# 0       NaN          Sao Tome  46.227638   2.213749
# 1       NaN              Togo  46.227638   2.213749
# 2       NaN              Togo  46.227638   2.213749
# 3       NaN              Togo  46.227638   2.213749
# 4       NaN              Peru  46.227638   2.213749

# %% [markdown]
# ### Data Information

# %%
dfr.describe()
# Out:
#        Review Date  Cocoa Percent       Rating     latitude    longitude
# count  1767.000000    1767.000000  1767.000000  1959.000000  1959.000000
# mean   2012.321449      71.676287     3.185767    32.577200   -39.812591
# std       2.937960       6.286314     0.475971    22.602646    70.223014
# min    2006.000000      42.000000     1.000000   -75.250973  -177.156097
# 25%    2010.000000      70.000000     2.875000    37.090240   -95.712891
# 50%    2013.000000      70.000000     3.250000    37.090240   -78.183406
# 75%    2015.000000      75.000000     3.500000    46.227638     4.469936
# max    2017.000000     100.000000     5.000000    77.553604   179.414413

# %%
dfr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1959 entries, 0 to 1987
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1767 non-null   object
#  1   Bar Area           1767 non-null   object
#  2   Review Date        1767 non-null   float64
#  3   Cocoa Percent      1767 non-null   float64
#  4   Location           1959 non-null   object
#  5   Rating             1767 non-null   float64
#  6   Bean Type          889 non-null    object
#  7   Broad Bean Origin  1693 non-null   object
#  8   latitude           1959 non-null   float64
#  9   longitude          1959 non-null   float64
# dtypes: float64(5), object(5)
# memory usage: 168.4+ KB

# %%
dfr.shape
# Out:
# (1959, 10)

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# **Top Chocolate Companies by Products**

# %%
companies = dfr["Company"].value_counts().to_frame().reset_index()
companies.columns = ["Company", "Chocolates"]
companies_10 = companies.head(10)
companies_10
# Out:
#                       Company  Chocolates
# 0                        Soma          47
# 1                      Bonnat          27
# 2                      Fresco          26
# 3                      Pralus          25
# 4                    A. Morin          23
# 5                    Guittard          22
# 6                       Arete          22
# 7                      Domori          22
# 8                    Valrhona          21
# 9  Hotel Chocolat (Coppeneur)          19

# %% [markdown]
# **Total Bars by Area**

# %%
bar_names = dfr["Bar Area"].value_counts().to_frame().reset_index()
bar_names.columns = ["Bar Area", "Shops"]
bar_names_10 = bar_names.head(10)
bar_names_10
# Out:
#              Bar Area  Shops
# 0          Madagascar     56
# 1                Peru     43
# 2             Ecuador     40
# 3  Dominican Republic     37
# 4           Venezuela     21
# 5           Sambirano     19
# 6               Chuao     19
# 7             Ocumare     17
# 8    Papua New Guinea     15
# 9               Ghana     15

# %% [markdown]
# **Most Reviews in Years**

# %%
reviews = dfr["Review Date"].value_counts().to_frame().reset_index()
reviews.columns = ["Review Date", "Total"]
reviews["Percentage"] = (reviews["Total"] / sum(reviews["Total"])) * 100
reviews
# Out:
#     Review Date  Total  Percentage
# 0        2015.0    277   15.676287
# 1        2014.0    247   13.978495
# 2        2016.0    219   12.393888
# 3        2012.0    188   10.639502
# 4        2013.0    176    9.960385
# 5        2011.0    165    9.337861
# 6        2009.0    123    6.960951
# 7        2010.0    109    6.168647
# 8        2008.0     90    5.093379
# 9        2007.0     77    4.357668
# 10       2006.0     72    4.074703
# 11       2017.0     24    1.358234

# %% [markdown]
# **Top Cocoa Percentages**

# %%
cocoa = dfr["Cocoa Percent"].value_counts().to_frame().reset_index()
cocoa.columns = ["Cocoa Percent", "Total"]
cocoa_10 = cocoa.head(10)
cocoa_10
# Out:
#    Cocoa Percent  Total
# 0           70.0    667
# 1           75.0    217
# 2           72.0    186
# 3           65.0     78
# 4           80.0     68
# 5           74.0     50
# 6           68.0     45
# 7           60.0     42
# 8           73.0     40
# 9           85.0     36

# %% [markdown]
# **Countries by most companies**

# %%
cl = dfr["Location"].value_counts().to_frame().reset_index()
cl.columns = ["Company Location", "Chocolates Sold"]
cl_10 = cl.head(10)
cl_10
# Out:
#   Company Location  Chocolates Sold
# 0    United States              764
# 1           France              156
# 2           Canada              125
# 3   United Kingdom               96
# 4            Italy               63
# 5          Ecuador               54
# 6        Australia               49
# 7          Belgium               40
# 8      Switzerland               38
# 9          Germany               35

# %% [markdown]
# **Most Ratings**

# %%
ratings = dfr["Rating"].value_counts().to_frame().reset_index()
ratings.columns = ["Ratings", "Total"]
ratings["Percentage"] = (ratings["Total"] / sum(ratings["Total"])) * 100
ratings
# Out:
#     Ratings  Total  Percentage
# 0      3.50    389   22.014714
# 1      3.00    336   19.015280
# 2      3.25    298   16.864743
# 3      2.75    254   14.374646
# 4      3.75    204   11.544992
# 5      2.50    126    7.130730
# 6      4.00     96    5.432937
# 7      2.00     32    1.810979
# 8      2.25     14    0.792303
# 9      1.50     10    0.565931
# 10     1.00      3    0.169779
# 11     1.75      3    0.169779
# 12     5.00      2    0.113186

# %% [markdown]
# **Top Bean Types used in Chocolates**

# %%
bc = dfr["Bean Type"].value_counts().to_frame().reset_index()
bc.columns = ["Bean Type", "Total"]
bc_10 = bc.head(10)
bc_10
# Out:
#                Bean Type  Total
# 0             Trinitario    416
# 1                Criollo    148
# 2              Forastero     81
# 3   Forastero (Nacional)     50
# 4                  Blend     41
# 5    Criollo, Trinitario     39
# 6     Forastero (Arriba)     36
# 7    Criollo (Porcelana)     10
# 8    Trinitario, Criollo      9
# 9  Forastero (Parazinho)      8

# %% [markdown]
# **Top Broad Bean Origins by Chocolates**

# %%
bbo = dfr["Broad Bean Origin"].value_counts().to_frame().reset_index()
bbo.columns = ["Broad Bean Origin", "Total"]
bbo_10 = bbo.head(10)
bbo_10
# Out:
#     Broad Bean Origin  Total
# 0           Venezuela    213
# 1             Ecuador    191
# 2                Peru    158
# 3          Madagascar    144
# 4  Dominican Republic    135
# 5           Nicaragua     59
# 6              Brazil     58
# 7             Bolivia     57
# 8              Belize     49
# 9    Papua New Guinea     42

# %% [markdown]
# ### Deep Insights

# %% [markdown]
# **Top Companies having products in bar area**

# %%
com_bar = dfr.groupby(["Company", "Bar Area"])["Bar Area"].agg(["count"]).reset_index().sort_values(by = "count", ascending = False)
com_bar = com_bar.drop_duplicates("Bar Area", keep = "first")
com_bar_10 = com_bar.head(10)
com_bar_10
# Out:
#                              Company                           Bar Area  count
# 1229                     Q Chocolate                             Brazil      6
# 1558   Vao Vao (Chocolaterie Robert)                         Madagascar      5
# 23                              AMMA  Monte Alegre, 3 diff. plantations      4
# 1443                  StRita Supreme         Samar, East Visayas region      3
# 79                            Amedei                      Toscano Black      3
# 1569  Vintage Plantations (Tulicorp)  Los Rios, Rancho Grande 2004/2007      3
# 1346                          Sirene             Somia Plantation, 2012      3
# 186              Bittersweet Origins                       Puerto Plata      3
# 187              Bittersweet Origins                          Sambirano      3
# 679            Grenada Chocolate Co.                            Grenada      3

# %% [markdown]
# **Reviews on Companies by Dates**

# %%
cd = dfr.groupby(["Review Date", "Company"])["Company"].agg(["count"]).reset_index().sort_values(by = "count", ascending = False)
cd = cd.drop_duplicates("Review Date", keep = "first")
cd
# Out:
#      Review Date                Company  count
# 14        2006.0                 Pralus     16
# 315       2012.0                  Tejas     14
# 599       2016.0                  Arete     13
# 325       2013.0               A. Morin     11
# 19        2007.0                 Amedei     10
# 550       2015.0          Map Chocolate      9
# 434       2014.0               Habitual      9
# 213       2011.0          Mast Brothers      9
# 67        2008.0  Kallari (Ecuatoriana)      8
# 137       2010.0          Cacao Sampaka      6
# 82        2009.0    Artisan du Chocolat      6
# 711       2017.0                   Soul      6

# %% [markdown]
# **Top 10 Average Cocoa Percent used by Companies**

# %%
cpm = dfr.groupby("Company")["Cocoa Percent"].agg(["mean", "max", "min"]).reset_index().sort_values(by = "mean", ascending = False).head(10)
cpm.columns = ["Company", "Avg Cocoa Percent", "Max Cocoa Percent", "Min Cocoa Percent"]
cpm
# Out:
#                             Company  Avg Cocoa Percent  Max Cocoa Percent  \
# 41           Bouga Cacao (Tulicorp)          88.500000              100.0
# 83       Chocolate Alchemist-Philly          85.000000               90.0
# 267                           Nanea          85.000000               85.0
# 217                Lindt & Sprungli          85.000000               85.0
# 156                   Garden Island          85.000000               85.0
# 387  Vintage Plantations (Tulicorp)          82.500000              100.0
# 298                         Peppalo          82.000000               82.0
# 127                          Durand          82.000000               82.0
# 240                        Marsatta          81.500000               89.0
# 30                         Belyzium          81.333333               83.0
#
#      Min Cocoa Percent
# 41                77.0
# 83                80.0
# 267               85.0
# 217               85.0
# 156               85.0
# 387               65.0
# 298               82.0
# 127               82.0
# 240               74.0
# 30                78.0

# %% [markdown]
# **Lowest 10 Cocoa Percent by Companies**

# %%
cpl = dfr.groupby("Company")["Cocoa Percent"].agg(["mean"]).reset_index().sort_values(by = "mean").head(10)
cpl.columns =["Company", "Avg Cocoa Percent"]
cpl
# Out:
#                                 Company  Avg Cocoa Percent
# 91               Chokolat Elot (Girard)              42.00
# 229                Malie Kai (Guittard)              55.00
# 32                            Bernachon              55.00
# 221                               Luker              57.25
# 288  Original Hawaiin Chocolate Factory              60.00
# 201                            Kiskadee              60.00
# 209                      La Pepa de Oro              60.00
# 375                          Two Ravens              60.00
# 140              Ethel's Artisan (Mars)              60.80
# 187                               Indah              61.00

# %% [markdown]
# **Companies with Rating 5**

# %%
cr_4 = dfr[dfr["Rating"] == 5]
cr_4.head(100)
# Out:
#      Company       Bar Area  Review Date  Cocoa Percent Location  Rating  \
# 1194  Amedei          Chuao       2007.0           70.0    Italy     5.0
# 1202  Amedei  Toscano Black       2006.0           70.0    Italy     5.0
#
#        Bean Type Broad Bean Origin  latitude  longitude
# 1194  Trinitario         Venezuela  41.87194   12.56738
# 1202       Blend               NaN  41.87194   12.56738

# %% [markdown]
# **Companies with ratings less than 2**

# %%
cr_2 = dfr[dfr["Rating"] < 2]
cr_2
# Out:
#                        Company                        Bar Area  Review Date  \
# 57                      Bonnat                     One Hundred       2006.0
# 146                   Valrhona              Le Noir Extra Amer       2007.0
# 644                 Middlebury                      Houseblend       2012.0
# 786          Snake & Butterfly                           Ghana       2011.0
# 927     Bouga Cacao (Tulicorp)         El Oro, Hacienda de Oro       2009.0
# 931    Cacaoyere (Ecuatoriana)                       Pichincha       2008.0
# 1055  Machu Picchu Trading Co.                            Peru       2011.0
# 1245                  S.A.I.D.                     100 percent       2010.0
# 1275       Artisan du Chocolat                       Venezuela       2010.0
# 1282       Artisan du Chocolat                 Brazil Rio Doce       2009.0
# 1324            Hotel Chocolat  Island Growers, 2012, 120hr c.       2013.0
# 1428                 Callebaut                          Baking       2007.0
# 1429        Cote d' Or (Kraft)              Sensations Intense       2006.0
# 1431        Dolfin (Belcolade)                            Noir       2006.0
# 1439       Neuhaus (Callebaut)                            Dark       2007.0
# 1464                 Coppeneur              Ecuador Puristique       2012.0
#
#       Cocoa Percent        Location  Rating           Bean Type  \
# 57            100.0          France    1.50                 NaN
# 146            85.0          France    1.50                 NaN
# 644            65.0   United States    1.50                 NaN
# 786            67.0   United States    1.50           Forastero
# 927           100.0         Ecuador    1.50  Forastero (Arriba)
# 931            91.0         Ecuador    1.50  Forastero (Arriba)
# 1055           70.0            Peru    1.50                 NaN
# 1245          100.0           Italy    1.50                 NaN
# 1275          100.0  United Kingdom    1.75                 NaN
# 1282           72.0  United Kingdom    1.75                 NaN
# 1324          100.0  United Kingdom    1.75          Trinitario
# 1428           70.0         Belgium    1.00                 NaN
# 1429           70.0         Belgium    1.00                 NaN
# 1431           70.0         Belgium    1.50                 NaN
# 1439           73.0         Belgium    1.00                 NaN
# 1464          100.0         Germany    1.50                 NaN
#
#      Broad Bean Origin   latitude  longitude
# 57                 NaN  46.227638   2.213749
# 146                NaN  46.227638   2.213749
# 644                NaN  37.090240 -95.712891
# 786              Ghana  37.090240 -95.712891
# 927            Ecuador  -1.831239 -78.183406
# 931            Ecuador  -1.831239 -78.183406
# 1055              Peru  -9.189967 -75.015152
# 1245               NaN  41.871940  12.567380
# 1275         Venezuela  55.378051  -3.435973
# 1282            Brazil  55.378051  -3.435973
# 1324         St. Lucia  55.378051  -3.435973
# 1428           Ecuador  50.503887   4.469936
# 1429               NaN  50.503887   4.469936
# 1431               NaN  50.503887   4.469936
# 1439               NaN  50.503887   4.469936
# 1464           Ecuador  51.165691  10.451526

# %% [markdown]
# **Broad Bean Origin used by Companies**

# %%
bboc = dfr.groupby(["Company", "Broad Bean Origin"])["Broad Bean Origin"].agg(["count"]).reset_index().sort_values(by = "count", ascending = False)
bboc = bboc.drop_duplicates("Broad Bean Origin", keep = "first")
bboc_10 = bboc.head(10)
bboc_10
# Out:
#                             Company Broad Bean Origin  count
# 370                          Domori         Venezuela     12
# 789                          Pacari           Ecuador     11
# 449             Friis Holm (Bonnat)         Nicaragua     11
# 663                           Marou           Vietnam     10
# 324                           Danta         Guatemala      7
# 203                   Cacao Hunters          Colombia      7
# 439                    French Broad              Peru      6
# 861                     Q Chocolate            Brazil      6
# 1104  Vao Vao (Chocolaterie Robert)        Madagascar      6
# 614                        Lonohana            Hawaii      6

# %% [markdown]
# **Average Cocoa Percent by Rating**

# %%
cpr = dfr.groupby("Rating")["Cocoa Percent"].agg(["mean", "max", "min"]).reset_index().sort_values(by = "Rating", ascending = False)
cpr.columns = ["Rating", "Avg Cocoa Percent", "Max Cocoa Percent", "Min Cocoa Percent"]
cpr
# Out:
#     Rating  Avg Cocoa Percent  Max Cocoa Percent  Min Cocoa Percent
# 12    5.00          70.000000               70.0               70.0
# 11    4.00          70.718750               88.0               60.0
# 10    3.75          70.764706               90.0               50.0
# 9     3.50          71.174807              100.0               55.0
# 8     3.25          71.489933               99.0               55.0
# 7     3.00          71.726190              100.0               55.0
# 6     2.75          72.202756              100.0               42.0
# 5     2.50          71.710317              100.0               55.0
# 4     2.25          74.000000              100.0               55.0
# 3     2.00          76.625000              100.0               53.0
# 2     1.75          90.666667              100.0               72.0
# 1     1.50          84.800000              100.0               65.0
# 0     1.00          71.000000               73.0               70.0

# %% [markdown]
# **Average Rating by Company Location**

# %%
arcl = dfr.groupby("Location")["Rating"].agg(["mean", "max", "min"]).reset_index().sort_values(by = "max", ascending = False)
arcl.columns = ["Company Location", "Avg Rating", "Max Rating", "Min Rating"]
arcl.dropna()
# Out:
#     Company Location  Avg Rating  Max Rating  Min Rating
# 107            Italy    3.325397        5.00        1.50
# 81           Germany    3.178571        4.00        1.50
# 12         Australia    3.357143        4.00        2.50
# 20           Belgium    3.093750        4.00        1.00
# 232    United States    3.154123        4.00        1.50
# 29            Brazil    3.397059        4.00        2.75
# 38            Canada    3.324000        4.00        2.00
# 231   United Kingdom    3.054688        4.00        1.75
# 47          Colombia    3.173913        4.00        2.00
# 210      Switzerland    3.342105        4.00        2.00
# 203            Spain    3.270000        4.00        2.50
# 89         Guatemala    3.350000        4.00        2.75
# 62           Ecuador    3.009259        4.00        1.50
# 129       Madagascar    3.147059        4.00        2.50
# 73            France    3.251603        4.00        1.50
# 125        Lithuania    3.166667        3.75        2.50
# 195        Singapore    3.333333        3.75        2.75
# 156      New Zealand    3.191176        3.75        2.50
# 175           Poland    3.375000        3.75        2.50
# 99           Iceland    3.416667        3.75        3.00
# 237        Venezuela    3.175000        3.75        2.50
# 106           Israel    3.250000        3.75        2.50
# 9          Argentina    3.305556        3.75        2.75
# 238          Vietnam    3.409091        3.75        3.00
# 98           Hungary    3.204545        3.75        2.25
# 13           Austria    3.240385        3.75        2.75
# 25           Bolivia    3.250000        3.75        2.75
# 43             Chile    3.750000        3.75        3.75
# 58           Denmark    3.283333        3.75        2.50
# 172             Peru    2.897059        3.50        1.50
# 52        Costa Rica    3.138889        3.50        2.50
# 209           Sweden    3.050000        3.50        2.75
# 202      South Korea    3.200000        3.50        2.75
# 173      Philippines    3.500000        3.50        3.50
# 71              Fiji    3.250000        3.50        2.75
# 96          Honduras    3.208333        3.50        2.75
# 109            Japan    3.088235        3.50        2.25
# 153      Netherlands    3.500000        3.50        3.50
# 72           Finland    3.250000        3.50        3.00
# 157        Nicaragua    3.000000        3.25        2.75
# 206         Suriname    3.250000        3.25        3.25
# 104          Ireland    2.812500        3.25        2.50
# 180           Russia    3.250000        3.25        3.25
# 86           Grenada    2.833333        3.25        2.50
# 140           Mexico    2.687500        3.00        2.00
# 200     South Africa    2.666667        3.00        2.50
# 176         Portugal    2.750000        3.00        2.50
# 56    Czech Republic    2.750000        2.75        2.75
# 136       Martinique    2.750000        2.75        2.75
# 82             Ghana    2.750000        2.75        2.75
# 177      Puerto Rico    2.625000        2.75        2.50
# 100            India    2.500000        2.50        2.50

# %% [markdown]
# **Average Rating by Years**

# %%
ary = dfr.groupby("Review Date")["Rating"].agg(["mean", "max", "min"]).reset_index().sort_values(by = "mean", ascending = False)
ary
# Out:
#     Review Date      mean   max   min
# 11       2017.0  3.312500  3.75  2.50
# 5        2011.0  3.256061  4.00  1.50
# 9        2015.0  3.234657  4.00  2.00
# 10       2016.0  3.226027  4.00  2.00
# 7        2013.0  3.196023  4.00  1.75
# 6        2012.0  3.191489  4.00  1.50
# 8        2014.0  3.189271  4.00  2.00
# 1        2007.0  3.162338  5.00  1.00
# 4        2010.0  3.144495  4.00  1.50
# 0        2006.0  3.125000  5.00  1.00
# 3        2009.0  3.073171  4.00  1.50
# 2        2008.0  3.005556  4.00  1.50

# %% [markdown]
# **Bar Area with Cocoa Percent 100**

# %%
bacp = dfr[dfr["Cocoa Percent"] == 100]

# %% [markdown]
# **Companies with  Highest average Rating and average Cocoa Percent**

# %%
ccpr = dfr.groupby("Company")[["Rating", "Cocoa Percent"]].agg(["mean"]).reset_index()
ccpr = ccpr.droplevel(1, axis = 1)
ccpr = ccpr.sort_values(by = ["Rating"], ascending = False)
ccpr_10 = ccpr.head(10)
ccpr_10
# Out:
#                                   Company    Rating  Cocoa Percent
# 371                Tobago Estate (Pralus)  4.000000      70.000000
# 178  Heirloom Cacao Preservation (Zokoko)  3.875000      70.000000
# 14                                 Amedei  3.846154      69.538462
# 243                                Matale  3.812500      71.000000
# 296                                Patric  3.791667      69.833333
# 186                     Idilio (Felchlin)  3.775000      72.000000
# 2                                  Acalli  3.750000      70.000000
# 376                   Un Dimanche A Paris  3.750000      63.000000
# 199                              Kerchner  3.750000      70.000000
# 369                         Timo A. Meyer  3.750000      72.000000

# %% [markdown]
# **Company Location with highest average Rating and Cocoa Percent**

# %%
clrc = dfr.groupby("Location")[["Rating", "Cocoa Percent"]].agg(["mean"]).reset_index()
clrc = clrc.droplevel(1, axis = 1)
clrc = clrc.sort_values(by = "Rating", ascending = False)
clrc_10 = clrc.head(10)
clrc_10
# Out:
#         Location    Rating  Cocoa Percent
# 43         Chile  3.750000      70.000000
# 173  Philippines  3.500000      65.000000
# 153  Netherlands  3.500000      70.000000
# 99       Iceland  3.416667      68.666667
# 238      Vietnam  3.409091      74.545455
# 29        Brazil  3.397059      69.823529
# 175       Poland  3.375000      71.875000
# 12     Australia  3.357143      70.224490
# 89     Guatemala  3.350000      70.200000
# 210  Switzerland  3.342105      71.210526

# %% [markdown]
# **Average Cocoa Percent and Average Rating by Review Date**

# %%
cprr = dfr.groupby("Review Date")[["Rating", "Cocoa Percent"]].agg(["mean"]).reset_index()
cprr = cprr.droplevel(1, axis = 1)
cprr = cprr.sort_values(by = "Rating", ascending = False)
cprr = cprr.reset_index()
cprr = cprr.drop(columns = ["index"])
cprr
# Out:
#     Review Date    Rating  Cocoa Percent
# 0        2017.0  3.312500      71.541667
# 1        2011.0  3.256061      70.969697
# 2        2015.0  3.234657      71.974729
# 3        2016.0  3.226027      71.757991
# 4        2013.0  3.196023      72.511364
# 5        2012.0  3.191489      71.420213
# 6        2014.0  3.189271      72.253036
# 7        2007.0  3.162338      72.038961
# 8        2010.0  3.144495      70.715596
# 9        2006.0  3.125000      71.000000
# 10       2009.0  3.073171      70.443089
# 11       2008.0  3.005556      72.288889

# %% [markdown]
# **Reviews in 2015 and 2014 by Locations**

# %%
rl = dfr[(dfr["Review Date"] == 2015.0) | (dfr["Review Date"] == 2014.0)]

# %%
from folium import plugins
map_world = folium.Map()
# instantiate a mark cluster object for the incidents in the dataframe
incidents = plugins.MarkerCluster().add_to(map_world)
# loop through the dataframe and add each data point to the mark cluster
for lat, lng, label, in zip(rl["latitude"], rl["longitude"], rl["Location"]):
    folium.Marker(
    location=[lat, lng],
    icon=None,
    popup=label,
    ).add_to(incidents)
# display map
map_world
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_f3d298f32f114a7d9ca44df19d33352c%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css%22/%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_f3d298f32f114a7d9ca44df19d33352c%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3 ...

# %% [markdown]
# **Maximum Cocoa Percent by Location**
